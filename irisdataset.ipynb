# %%
import math
import pandas as pd
from operator import itemgetter

# %%
dataset=pd.read_csv("/kaggle/input/d/vikrishnan/iris-dataset/iris.data.csv",header=None)
dataset.columns = ['SepalLengthCm'  ,'SepalWidthCm'  ,'PetalLengthCm'  ,'PetalWidthCm','Species']
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn import tree
model=tree.DecisionTreeClassifier(criterion='entropy',max_depth=8,splitter='best')
model.fit(X_train,y_train)
predictions=model.predict(X_test)

# %%
y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  2 10]]
# 0.9473684210526315

# %%
from sklearn.datasets import load_iris
from sklearn import tree
tree.plot_tree(model)
# Out:
# [Text(0.3333333333333333, 0.9375, 'x[2] <= -0.787\nentropy = 1.583\nsamples = 112\nvalue = [35, 39, 38]'),
#  Text(0.2222222222222222, 0.8125, 'entropy = 0.0\nsamples = 35\nvalue = [35, 0, 0]'),
#  Text(0.4444444444444444, 0.8125, 'x[2] <= 0.546\nentropy = 1.0\nsamples = 77\nvalue = [0, 39, 38]'),
#  Text(0.2222222222222222, 0.6875, 'x[3] <= 0.585\nentropy = 0.187\nsamples = 35\nvalue = [0, 34, 1]'),
#  Text(0.1111111111111111, 0.5625, 'entropy = 0.0\nsamples = 34\nvalue = [0, 34, 0]'),
#  Text(0.3333333333333333, 0.5625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6666666666666666, 0.6875, 'x[2] <= 0.777\nentropy = 0.527\nsamples = 42\nvalue = [0, 5, 37]'),
#  Text(0.5555555555555556, 0.5625, 'x[3] <= 0.719\nentropy = 0.896\nsamples = 16\nvalue = [0, 5, 11]'),
#  Text(0.3333333333333333, 0.4375, 'x[1] <= -1.587\nentropy = 0.918\nsamples = 6\nvalue = [0, 4, 2]'),
#  Text(0.2222222222222222, 0.3125, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.4444444444444444, 0.3125, 'x[2] <= 0.719\nentropy = 0.722\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.3333333333333333, 0.1875, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.5555555555555556, 0.1875, 'x[1] <= -0.661\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.4444444444444444, 0.0625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6666666666666666, 0.0625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7777777777777778, 0.4375, 'x[1] <= 0.149\nentropy = 0.469\nsamples = 10\nvalue = [0, 1, 9]'),
#  Text(0.6666666666666666, 0.3125, 'entropy = 0.0\nsamples = 9\nvalue = [0, 0, 9]'),
#  Text(0.8888888888888888, 0.3125, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7777777777777778, 0.5625, 'entropy = 0.0\nsamples = 26\nvalue = [0, 0, 26]')]
